# %%
import pandas as pd

# %%
import numpy as np

# %%
import scipy as sp

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("/Users/xousaenhelu/Downloads/minutes1494645.csv")
data
# Out:
#                Date   Time Incoming/Outgoing       Phone Nickname  \
# 0    March 03, 2015  12:12          incoming  9098010780  Xousaen
# 1    March 03, 2015  12:11          outgoing  9517046044  Maryana
# 2    March 03, 2015  17:55          outgoing  9517046044  Maryana
# 3    March 03, 2015  18:23          outgoing  9098010780  Xousaen
# 4    March 03, 2015  18:23          incoming  9517046044  Maryana
# 5    March 03, 2015  21:28          incoming  9098010780  Xousaen
# 6    March 04, 2015  15:08          outgoing  9517046044  Maryana
# 7    March 04, 2015  16:32          outgoing  9517046044  Maryana
# 8    March 04, 2015  16:31          outgoing  9517046044  Maryana
# 9    March 04, 2015  16:38          outgoing  9517046044  Maryana
# 10   March 04, 2015  17:00          outgoing  9098010780  Xousaen
# 11   March 04, 2015  17:00          incoming  9517046044  Maryana
# 12   March 04, 2015  17:25          outgoing  9098010780  Xousaen
# ...

# %%
data.groupby('Nickname').sum()
# Out:
#                  Phone  Partner's Phone  Duration (min)  Surcharges ($)
# Nickname
# Armando    54566142276     5.458806e+10               6               0
# Mama      254744302512     2.126117e+11              74               0
# Maryana   742329591432     7.063151e+11             128               0
# Xousaen   591370700700     1.634921e+12             164               0

# %%
data2 = data.groupby('Nickname').sum()
data2.iloc[:, 2]
# Out:
# Nickname
# Armando       6
# Mama         74
# Maryana     128
# Xousaen     164
# Name: Duration (min), dtype: int64

# %%
data3 = data2.iloc[:, 2]
data3.sum()
# Out:
# 372

# %%
data3.index
# Out:
# Index([u'Armando', u'Mama', u'Maryana', u'Xousaen'], dtype='object')

# %%
plt.pie(data3, labels = data3.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Minutes Used in March')
plt.show()

# %%
from numpy import array
from numpy import random
a = array([2,3,4,5])
b = array([9,8,7,6])
c = a * b
c
d = random.random((1,4))
d *= a
d
# Out:
# array([[ 1.35037085,  1.95154351,  1.15373032,  3.82276339]])

# %%
plt.plot(c, 'r^')
plt.title('Numpy Plot Using Arrays #1')
plt.show()

# %%
a1 = array([(2,3,4), (5,4,3)])
a1
# Out:
# array([[2, 3, 4],
#        [5, 4, 3]])

# %%
plt.plot(a1)
plt.title('Numpy Plot Using Arrays #2')
plt.show()

# %%
print a1
# Out:
# [[2 3 4]
#  [5 4 3]]

# %%
a1.sum(axis=1)
# Out:
# array([ 9, 12])

# %%
a1.sum(axis=0)
# Out:
# array([7, 7, 7])

# %%
a1.cumsum(axis=1)
# Out:
# array([[ 2,  5,  9],
#        [ 5,  9, 12]])

# %%
a1.cumsum(axis=0)
# Out:
# array([[2, 3, 4],
#        [7, 7, 7]])

# %%
b1 = array([x**3 for x in range(12) if x % 2 != 0])
b1
# Out:
# array([   1,   27,  125,  343,  729, 1331])

# %%
b1[4]
# Out:
# 729
